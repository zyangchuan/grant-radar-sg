# %%
import os
import json
import requests
import argparse
from typing import List

# %%
# LangChain & AI Imports
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_core.tools import tool
from langchain.agents import create_agent
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# ==========================================
# 1. GLOBAL RESOURCE INITIALIZATION
# ==========================================
# We load the embedding model once at startup to improve performance.
print("[System] Initializing Embedding Model (all-MiniLM-L6-v2)...")
model_name = "sentence-transformers/all-MiniLM-l6-v2"
embeddings = HuggingFaceEmbeddings(model_name=model_name)

# Initialize Vector DB Connection
# We use the same directory for both writing (ingestion) and reading (agent).
DB_DIRECTORY = "./chroma_grants_db"
COLLECTION_NAME = "oursg_grants"

vector_store = Chroma(
    persist_directory=DB_DIRECTORY,
    embedding_function=embeddings,
    collection_name=COLLECTION_NAME
)
print("[System] Vector Database Connected.")
# Out:
# [System] Initializing Embedding Model (all-MiniLM-L6-v2)...
# [System] Vector Database Connected.

# %%
# ==========================================
# 2. INGESTION LOGIC (ETL)
# ==========================================
def fetch_and_store_grants():
    """Fetches JSON from API, processes it, and stores embeddings in ChromaDB."""
    url = "https://oursggrants.gov.sg/api/v1/grant_metadata/explore_grants"
    print(f"\n[Ingest] Fetching data from {url}...")

    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
    except Exception as e:
        print(f"[Error] Failed to fetch data: {e}")
        return

    grants_list = data.get("grant_metadata", [])
    documents = []

    print(f"[Ingest] Processing {len(grants_list)} grants...")

    for grant in grants_list:
        # Create a rich natural language description for the AI to search against
        page_content = (
            f"Grant Name: {grant.get('name', 'Unknown')}\n"
            f"Agency: {grant.get('agency_name', 'Unknown')}\n"
            f"Description: {grant.get('desc', '')}\n"
            f"Target Audience: {', '.join(grant.get('applicable_to', []))}"
        )

        # Sanitize metadata (ChromaDB requires flat types: str, int, float, bool)
        metadata = {
            "id": grant.get("id", ""),
            "name": grant.get("name", "Unknown"),
            "agency_name": grant.get("agency_name", "Unknown"),
            "funding_amount": float(grant.get("grant_amount") or 0.0),
            "updated_at": grant.get("updated_at", "")
        }

        documents.append(Document(page_content=page_content, metadata=metadata))

    if documents:
        print(f"[Ingest] Saving {len(documents)} vectors to disk...")
        # .add_documents will append to the existing DB defined globally
        vector_store.add_documents(documents)
        print("[Ingest] Success! Database updated.")
    else:
        print("[Ingest] No documents found to process.")

fetch_and_store_grants()
# Out:
# [Ingest] Fetching data from https://oursggrants.gov.sg/api/v1/grant_metadata/explore_grants...
# [Ingest] Processing 60 grants...
# [Ingest] Saving 60 vectors to disk...
# [Ingest] Success! Database updated.

# %%
@tool
def search_grants_database(query: str) -> str:
    """
    Searches the grants database for relevant schemes based on a natural language query.
    Returns the top 5 matching grants with their IDs, names, and descriptions.
    """
    print(f"\n  >> [Tool Call] Searching DB for: '{query}'")
    results = vector_store.similarity_search(query, k=5)
    
    output = []
    for doc in results:
        output.append(
            f"ID: {doc.metadata['id']}\n"
            f"Name: {doc.metadata['name']}\n"
            f"Agency: {doc.metadata['agency_name']}\n"
            f"Snippet: {doc.page_content[:200]}...\n---"
        )
    return "\n".join(output)

# %%
from langchain.messages import HumanMessage
system_prompt = (
        "You are an expert Grants Retrieval Agent for the Singapore Government."
        "Your task is to analyze the user's project requirements (provided in JSON) "
        "and identify the most relevant grants from the database.\n\n"
        "STEPS:\n"
        "1. Analyze the 'issue_area', 'scope_of_grant', and 'KPIs' from the input.\n"
        "2. Use the 'search_grants_database' tool to find matches. Construct a search query "
        "that focuses on the semantic meaning of the project (e.g., 'youth mentorship sports').\n"
        "3. Filter the results. Ignore grants that are clearly for different domains.\n"
        "4. FINAL OUTPUT: Return ONLY a JSON list of the matching Grant IDs. Example: [\"id1\", \"id2\"]."
    )

def create_grant_query_agent():
    """Creates and returns an agent for querying the grants database."""
    agent = create_agent(
        model="gpt-3.5-turbo",
        tools=[search_grants_database],
        system_prompt=system_prompt,
    )
    return agent

# %%
main_agent = create_grant_query_agent()

# %%
from pprint import pprint
query={
    "issue_area": "environmental sustainability",
    "scope_of_grant": "community projects focused on reducing plastic waste",
    "KPIs": [
        "amount of plastic waste reduced",
        "number of community members engaged in sustainability initiatives"
    ]
}
response = main_agent.invoke(HumanMessage(content=json.dumps(query)))
pprint(response)
grant_list = json.loads(response["messages"][-1].content)
print(grant_list)
# Out:
#   >> [Tool Call] Searching DB for: 'youth mentorship sports'
#
#   >> [Tool Call] Searching DB for: 'community engagement development'
#
#   >> [Tool Call] Searching DB for: 'technology education innovation'
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 214, 'total_tokens': 285, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CxDV4uKTRQpHjRw28hi6eU7KnxfZn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bb2ad-a230-73c3-8154-3960f650795c-0', tool_calls=[{'name': 'search_grants_database', 'args': {'query': 'youth mentorship sports'}, 'id': 'call_cusf7GfnPVFsyQ0pIFDKCkiz', 'type': 'tool_call'}, {'name': 'search_grants_database', 'args': {'query': 'community engagement development'}, 'id': 'call_pbpWbfgfkqlq5JsboNXQFlWo', 'type': 'tool_call'}, {'name': 'search_grants_database', 'args': {'query': 'technology education innovation'}, 'id': 'call_jqNd4sKXH51zUnEJqQBnZFqa', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 71, 'total_tokens': 285, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='ID: hzNXqGyUXQsgxSQ5AvdwZ4aR\nName: Youth Corps Expedition Project\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Expedition Project\nAgency: National Youth Council\nDescription: Supports youths embarking on Service-Learning projects involving communities in Asia, with a focus on the ASEAN m...\n---\nID: hzNXqGyUXQsgxSQ5AvdwZ4aR\nName: Youth Corps Expedition Project\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Expedition Project\nAgency: National Youth Council\nDescription: Supports youths embarking on Service-Learning projects involving communities in Asia, with a focus on the ASEAN m...\n---\nID: uzN8p7SaZKKtnE7VyoBxWTr8\nName: Youth Corps Aspirant Project (YCAP)\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Aspirant Project (YCAP)\nAgency: National Youth Council\nDescription: The Youth Corps Aspirant Project (YCAP) Grant is open to all aspirant project teams in the Youth Corps Leade...\n---\nID: uzN8p7SaZKKtnE7VyoBxWTr8\nName: Youth Corps Aspirant Project (YCAP)\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Aspirant Project (YCAP)\nAgency: National Youth Council\nDescription: The Youth Corps Aspirant Project (YCAP) Grant is open to all aspirant project teams in the Youth Corps Leade...\n---\nID: DuabSGhh2TYZ2KhALea3Y4WK\nName: Youth Corps Cluster Project Grant (YCCL)\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Cluster Project Grant (YCCL)\nAgency: National Youth Council\nDescription: The Youth Corps Cluster Project Grant supports Cluster-initiated projects that drive a positive impact ...\n---', name='search_grants_database', id='4c094a82-486b-47cf-98af-306920be99a9', tool_call_id='call_cusf7GfnPVFsyQ0pIFDKCkiz'),
#               ToolMessage(content="ID: DuabSGhh2TYZ2KhALea3Y4WK\nName: Youth Corps Cluster Project Grant (YCCL)\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Cluster Project Grant (YCCL)\nAgency: National Youth Council\nDescription: The Youth Corps Cluster Project Grant supports Cluster-initiated projects that drive a positive impact ...\n---\nID: DuabSGhh2TYZ2KhALea3Y4WK\nName: Youth Corps Cluster Project Grant (YCCL)\nAgency: National Youth Council\nSnippet: Grant Name: Youth Corps Cluster Project Grant (YCCL)\nAgency: National Youth Council\nDescription: The Youth Corps Cluster Project Grant supports Cluster-initiated projects that drive a positive impact ...\n---\nID: oR7BVvduir35TU92pL2gR9zV\nName: OUR SINGAPORE FUND (Community)\nAgency: Ministry of Culture, Community and Youth\nSnippet: Grant Name: OUR SINGAPORE FUND (Community)\nAgency: Ministry of Culture, Community and Youth\nDescription: Have an idea for projects that bring communities together, that promotes Singapore's national i...\n---\nID: oR7BVvduir35TU92pL2gR9zV\nName: OUR SINGAPORE FUND (Community)\nAgency: Ministry of Culture, Community and Youth\nSnippet: Grant Name: OUR SINGAPORE FUND (Community)\nAgency: Ministry of Culture, Community and Youth\nDescription: Have an idea for projects that bring communities together, that promotes Singapore's national i...\n---\nID: smS7RNNzbA1uavVZrWvuih71\nName: Community Integration Fund\nAgency: Ministry of Culture, Community and Youth\nSnippet: Grant Name: Community Integration Fund\nAgency: Ministry of Culture, Community and Youth\nDescription: The CIF supports ground-up projects which create more opportunities for locals and foreigners to in...\n---", name='search_grants_database', id='dfcd49ac-4519-49e3-b3db-93df0c32a730', tool_call_id='call_pbpWbfgfkqlq5JsboNXQFlWo'),
#               ToolMessage(content='ID: D3jmp2ip3ebo77938XerjiHc\nName: Enterprise Innovation and Capability Development Grant (InnoGrant) \nAgency: Sport Singapore\nSnippet: Grant Name: Enterprise Innovation and Capability Development Grant (InnoGrant) \nAgency: Sport Singapore\nDescription: InnoGrant seeks innovative technological solutions to revolutionise sport and fitne...\n---\nID: D3jmp2ip3ebo77938XerjiHc\nName: Enterprise Innovation and Capability Development Grant (InnoGrant) \nAgency: Sport Singapore\nSnippet: Grant Name: Enterprise Innovation and Capability Development Grant (InnoGrant) \nAgency: Sport Singapore\nDescription: InnoGrant seeks innovative technological solutions to revolutionise sport and fitne...\n---\nID: 8j3AnMcEygdDiehpLM8so4iG\nName: SG Cyber Talent Development Fund\nAgency: Cyber Security Agency of Singapore\nSnippet: Grant Name: SG Cyber Talent Development Fund\nAgency: Cyber Security Agency of Singapore\nDescription: The SG Cyber Talent Development fund supports projects that engage, upskill or train individuals to...\n---\nID: 8j3AnMcEygdDiehpLM8so4iG\nName: SG Cyber Talent Development Fund\nAgency: Cyber Security Agency of Singapore\nSnippet: Grant Name: SG Cyber Talent Development Fund\nAgency: Cyber Security Agency of Singapore\nDescription: The SG Cyber Talent Development fund supports projects that engage, upskill or train individuals to...\n---\nID: qumQ8Njnp9ao55Bdn4GhTyoi\nName: Productivity and Digitalisation Grant (PDG)\nAgency: Agency for Integrated Care\nSnippet: Grant Name: Productivity and Digitalisation Grant (PDG)\nAgency: Agency for Integrated Care\nDescription: PDG supports the sector’s needs by focusing on 5 strategic areas, while promoting productivity a...\n---', name='search_grants_database', id='b8877446-0eb9-4438-b42c-2815cc16acc1', tool_call_id='call_jqNd4sKXH51zUnEJqQBnZFqa'),
#               AIMessage(content='{\n  "matching_grants": [\n    "hzNXqGyUXQsgxSQ5AvdwZ4aR",\n    "uzN8p7SaZKKtnE7VyoBxWTr8",\n    "DuabSGhh2TYZ2KhALea3Y4WK",\n    "oR7BVvduir35TU92pL2gR9zV",\n    "smS7RNNzbA1uavVZrWvuih71",\n    "D3jmp2ip3ebo77938XerjiHc",\n    "8j3AnMcEygdDiehpLM8so4iG",\n    "qumQ8Njnp9ao55Bdn4GhTyoi"\n  ]\n}', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 1560, 'total_tokens': 1729, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CxDV82yvRNzOtDsGwxRiH9i9Z45km', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bb2ad-aedd-72e1-a4a2-65da7be0bf92-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1560, 'output_tokens': 169, 'total_tokens': 1729, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'matching_grants': ['hzNXqGyUXQsgxSQ5AvdwZ4aR', 'uzN8p7SaZKKtnE7VyoBxWTr8', 'DuabSGhh2TYZ2KhALea3Y4WK', 'oR7BVvduir35TU92pL2gR9zV', 'smS7RNNzbA1uavVZrWvuih71', 'D3jmp2ip3ebo77938XerjiHc', '8j3AnMcEygdDiehpLM8so4iG', 'qumQ8Njnp9ao55Bdn4GhTyoi']}

# %%
import requests

def get_grants_from_ids(target_ids, all_grants_data=None):
    """
    Takes a list of Grant IDs and returns the full grant details.
    
    Args:
        target_ids (list): List of strings, e.g. ["id1", "id2"]
        all_grants_data (list, optional): Pass your existing full list of grants here 
                                          if you have it in memory. If None, it fetches 
                                          fresh data from the API.
    """
    # 1. Get the source data (API or Local)
    if all_grants_data is None:
        print("Fetching fresh data from API for lookup...")
        try:
            url = "https://oursggrants.gov.sg/api/v1/grant_metadata/explore_grants"
            response = requests.get(url)
            response.raise_for_status()
            data = response.json()
            all_grants_data = data.get("grant_metadata", [])
        except Exception as e:
            print(f"Error fetching data: {e}")
            return []

    # 2. Convert target_ids to a set for faster lookup
    target_set = set(target_ids)
    
    # 3. Filter the full list to find matches
    matched_grants = [
        grant for grant in all_grants_data 
        if grant.get("id") in target_set
    ]
    
    return matched_grants

matched_grants = get_grants_from_ids(grant_list)
print("\n[Final Result] Matching Grants:")
pprint(matched_grants)
# Out:
# Fetching fresh data from API for lookup...
#
# [Final Result] Matching Grants:
# [{'active': 'true',
#   'agency_code': 'aic',
#   'agency_icon_url': '/AgencyIcon/aic/AIC-Main Logo RGB.jpg',
#   'agency_name': 'Agency for Integrated Care',
#   'applicable_to': ['organisation'],
#   'available': {'individual': False, 'organisation': True},
#   'closing_dates': {'organisation': 'Open for Applications'},
#   'deactivated_grant_scheme': None,
#   'deactivation_url': 'https://www.aic.sg/partners/digital-transformation-plan',
#   'deliverables': [],
#   'desc': 'PDG supports the sector’s needs by focusing on 5 strategic areas, '
#           'while promoting productivity and digitalisation.',
#   'enabled': 'true',
#   'explorable_categories': [],
#   'grant_amount': None,
#   'how_to_apply_html': 'Complete the application, which should take about 30 '
#                        'mins if you have the information on hand. All fields '
#                        'are necessary unless they are marked as optional.',
#   'icon_url': None,
#   'id': 'qumQ8Njnp9ao55Bdn4GhTyoi',
#   'is_cumulus_enabled': 'false',
#   'name': 'Productivity and Digitalisation Grant (PDG)',
#   'need_signed_loa': False,
#   'open_grant': True,
#   'prelogin_status': {},
#   'started': True,
#   'status': 'green',
#   'updated_at': '2025-07-07',
#   'value': 'aicpdg'},
#  {'active': 'true',
#   'agency_code': 'nyc',
#   'agency_icon_url': '/AgencyIcon/nyc/nyc.png',
#   'agency_name': 'National Youth Council',
#   'applicable_to': ['individual'],
#   'available': {'individual': True, 'organisation': False},
#   'closing_dates': {'individual': 'Open for Applications'},
#   'deactivated_grant_scheme': None,
#   'deactivation_url': 'https://www.nyc.gov.sg/',
#   'deliverables': [],
#   'desc': 'Programme X Fundings supports youth-initiated projects, enabling '
#           'young changemakers to drive positive change in the Singapore '
#           'community and society.',
#   'enabled': 'true',
#   'explorable_categories': ['Care',
#                             'Community',
#                             'Education/Learning',
#                             'Health',
#                             'Social Cohesion',
#                             'Social Service',
#                             'Youth',
#                             'Environment',
#                             'Digital Skills/Tools'],
#   'grant_amount': 3000.0,
#   'how_to_apply_html': 'Completing the grant application should take about 30 '
#                        'mins with all the information on hand. All fields are '
#                        'mandatory unless otherwise stated.',
#   'icon_url': None,
#   'id': 'Sgi6jUHY1bT4crdgEpAcdhBp',
#   'is_cumulus_enabled': 'false',
#   'name': 'Programme X Fund',
#   'need_signed_loa': False,
#   'open_grant': True,
#   'prelogin_status': {},
#   'started': True,
#   'status': 'green',
#   'updated_at': '2025-12-22',
#   'value': 'nycpxfopn'},
#  {'active': 'true',
#   'agency_code': 'csa',
#   'agency_icon_url': '/AgencyIcon/csa/grant_card_icon-CSA.svg',
#   'agency_name': 'Cyber Security Agency of Singapore',
#   'applicable_to': ['individual', 'organisation'],
#   'available': {'individual': False, 'organisation': False},
#   'closing_dates': {'individual': 'Applications closed',
#                     'organisation': 'Applications closed'},
#   'deactivated_grant_scheme': None,
#   'deactivation_url': 'https://www.csa.gov.sg/sgcybertalentdevelopmentfund',
#   'deliverables': ['Classes/Seminar/Workshop',
#                    'Dialogue/Conversation',
#                    'Event/Exhibition/Performance',
#                    'Music/Video',
#                    'Publication',
#                    'Apps/Social Media/Website'],
#   'desc': 'The SG Cyber Talent Development fund supports projects that engage, '
#           'upskill or train individuals to explore, grow their passions for '
#           'and develop their careers in cybersecurity.',
#   'enabled': 'true',
#   'explorable_categories': ['Care',
#                             'Community',
#                             'Education/Learning',
#                             'Engagement Marketing',
#                             'Health',
#                             'Social Cohesion',
#                             'Social Service',
#                             'Sport',
#                             'Youth',
#                             'Digital Skills/Tools'],
#   'grant_amount': None,
#   'how_to_apply_html': 'Completing the grant application should take about 30 '
#                        'mins with all the information on hand. All fields are '
#                        'mandatory unless otherwise stated.',
#   'icon_url': None,
#   'id': '8j3AnMcEygdDiehpLM8so4iG',
#   'is_cumulus_enabled': 'false',
#   'name': 'SG Cyber Talent Development Fund',
#   'need_signed_loa': False,
#   'open_grant': True,
#   'prelogin_status': {},
#   'started': True,
#   'status': 'red',
#   'updated_at': '2022-01-12',
#   'value': 'csactdf'},
#  {'active': 'true',
#   'agency_code': 'nyc',
#   'agency_icon_url': '/AgencyIcon/nyc/nyc.png',
#   'agency_name': 'National Youth Council',
#   'applicable_to': ['individual', 'organisation'],
#   'available': True,
#   'closing_dates': {'individual': 'Open for Applications',
#                     'organisation': 'Open for Applications'},
#   'deactivated_grant_scheme': None,
#   'deactivation_url': 'https://www.youthcorps.gov.sg/volunteer/youth-expedition-project',
#   'deliverables': [],
#   'desc': 'Supports youths embarking on Service-Learning projects involving '
#           'communities in Asia, with a focus on the ASEAN member states, China '
#           'and India.',
#   'enabled': 'true',
#   'explorable_categories': ['Youth', 'Community'],
#   'grant_amount': 20000.0,
#   'how_to_apply_html': '<div>Complete all the fields on the <b '
#                        "style='color:#222'>application form</b> and the <b "
#                        "style='color:#222'>additional templates provided "
#                        'below</b>.<br><br>The application should take about 30 '
#                        'minutes to complete with all the information on '
#                        'hand.</div>',
#   'icon_url': None,
#   'id': 'hzNXqGyUXQsgxSQ5AvdwZ4aR',
#   'is_cumulus_enabled': 'false',
#   'name': 'Youth Corps Expedition Project',
#   'need_signed_loa': False,
#   'open_grant': True,
#   'prelogin_status': {},
#   'started': True,
#   'status': 'green',
#   'updated_at': '2025-11-26',
#   'value': 'yep'},
#  {'active': 'true',
#   'agency_code': 'nyc',
#   'agency_icon_url': '/AgencyIcon/nyc/nyc.png',
#   'agency_name': 'National Youth Council',
#   'applicable_to': ['individual'],
#   'available': {'individual': True, 'organisation': False},
#   'closing_dates': {'individual': 'Open for Applications'},
#   'deactivated_grant_scheme': None,
#   'deactivation_url': 'https://go.gov.sg/ycs-yep',
#   'deliverables': [],
#   'desc': 'YEP-GO is a platform for youths to continue volunteering with the '
#           'overseas communities without travel. Youths can connect with '
#           'overseas partner organisations to develop programmes through '
#           'virtual means.',
#   'enabled': 'true',
#   'explorable_categories': ['Community', 'Youth'],
#   'grant_amount': 3000.0,
#   'how_to_apply_html': 'Completing the grant application should take about 30 '
#                        'mins with all the information on hand. All fields are '
#                        'mandatory unless otherwise stated.',
#   'icon_url': None,
#   'id': 'aSnrhpqacMRotca9U2hw3rJY',
#   'is_cumulus_enabled': 'false',
#   'name': 'Youth Expedition Project Goes Online (YEP-GO)',
#   'need_signed_loa': False,
#   'open_grant': True,
#   'prelogin_status': {},
#   'started': True,
#   'status': 'green',
#   'updated_at': '2025-10-27',
#   'value': 'nycyepgo'}]
